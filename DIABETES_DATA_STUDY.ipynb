# %% [markdown]
# # Project Discussion Diabetes

# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("diabetes.csv")

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      diabetespedigreefunction  age  outcome
# 0                       0.627   50        1
# ...

# %%
df1.head()
# Out:
#    pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    diabetespedigreefunction  age  outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df1.tail()
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      diabetespedigreefunction  age  outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df1.sample(6)
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 680            2       56             56             28       45  24.2
# 392            1      131             64             14      415  23.7
# 337            5      115             76              0        0  31.2
# 312            2      155             74             17       96  26.6
# 394            4      158             78              0        0  32.9
# 533            6       91              0              0        0  29.8
#
#      diabetespedigreefunction  age  outcome
# 680                     0.332   22        0
# 392                     0.389   21        0
# 337                     0.343   44        1
# 312                     0.433   27        1
# 394                     0.803   31        1
# 533                     0.501   31        0

# %%
df1.columns
# Out:
# Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')

# %%
df1.shape
# Out:
# (768, 9)

# %%
df1.isnull().sum()
# Out:
# pregnancies                 0
# glucose                     0
# bloodpressure               0
# skinthickness               0
# insulin                     0
# bmi                         0
# diabetespedigreefunction    0
# age                         0
# outcome                     0
# dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # IMPUTATION

# %% [markdown]
# *categorical columns ==> mode/frequent
# *continous columns ==> mean/median

# %% [markdown]
# df1['diabetespedigreefunction'].fillna(value=df['diabetespedigreefunction'].median())

# %% [markdown]
# # EDA

# %% [markdown]
# 1.)     Desriptive Analysis
# 2.)    null value analysis
# 3.)    visualization
# 4.)     herarhial visualization
# 5.)    corealation
# 6.)     skewness,kurtosis,moments

# %% [markdown]
# # Machine learning preruisite
# 1.  no outliers
# 2    data- normal distributution
# 3.    no  null values

# %% [markdown]
# # Scatterplot:

# %%
import seaborn as sns

# %%
sns.scatterplot(x='pregnancies',y='outcome',data=df1)
# Out:
# <AxesSubplot:xlabel='pregnancies', ylabel='outcome'>

# %%
sns.scatterplot(x='glucose',y='outcome',data=df1)
# Out:
# <AxesSubplot:xlabel='glucose', ylabel='outcome'>

# %%
sns.scatterplot(x='bloodpressure',y='outcome',data=df1)
# Out:
# <AxesSubplot:xlabel='bloodpressure', ylabel='outcome'>

# %%
sns.scatterplot(x='insulin',y='outcome',data=df1)
# Out:
# <AxesSubplot:xlabel='insulin', ylabel='outcome'>

# %%
sns.scatterplot(x='skinthickness',y='outcome',data=df1)
# Out:
# <AxesSubplot:xlabel='skinthickness', ylabel='outcome'>

# %%
sns.scatterplot(x='bmi',y='outcome',data=df1)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='outcome'>

# %%
sns.scatterplot(x='diabetespedigreefunction',y='outcome',data=df1)
# Out:
# <AxesSubplot:xlabel='diabetespedigreefunction', ylabel='outcome'>

# %%
sns.scatterplot(x='age',y='outcome',data=df1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='outcome'>

# %%
import matplotlib.pyplot as plt
sns.pairplot(df1)
plt.savefig('pairplot.png')
plt.show()**************************************************************

# %%
df1.corr()
# Out:
#                           pregnancies   glucose  bloodpressure  skinthickness  \
# pregnancies                  1.000000  0.129459       0.141282      -0.081672
# glucose                      0.129459  1.000000       0.152590       0.057328
# bloodpressure                0.141282  0.152590       1.000000       0.207371
# skinthickness               -0.081672  0.057328       0.207371       1.000000
# insulin                     -0.073535  0.331357       0.088933       0.436783
# bmi                          0.017683  0.221071       0.281805       0.392573
# diabetespedigreefunction    -0.033523  0.137337       0.041265       0.183928
# age                          0.544341  0.263514       0.239528      -0.113970
# outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            insulin       bmi  diabetespedigreefunction  \
# pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
df1.corr()['outcome'].sort_values()
# Out:
# bloodpressure               0.065068
# skinthickness               0.074752
# insulin                     0.130548
# diabetespedigreefunction    0.173844
# pregnancies                 0.221898
# age                         0.238356
# bmi                         0.292695
# glucose                     0.466581
# outcome                     1.000000
# Name: outcome, dtype: float64

# %% [markdown]
# corelation using heatmap:

# %%
import matplotlib.pyplot as plt
# size of canvas
plt.figure(figsize=(15,7))
sns.heatmap(df1.corr(), annot=True,linewidths=1,linecolor="black", fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df1.describe()[1:]
# Out:
#       pregnancies     glucose  bloodpressure  skinthickness     insulin  \
# mean     3.845052  120.894531      69.105469      20.536458   79.799479
# std      3.369578   31.972618      19.355807      15.952218  115.244002
# min      0.000000    0.000000       0.000000       0.000000    0.000000
# 25%      1.000000   99.000000      62.000000       0.000000    0.000000
# 50%      3.000000  117.000000      72.000000      23.000000   30.500000
# 75%      6.000000  140.250000      80.000000      32.000000  127.250000
# max     17.000000  199.000000     122.000000      99.000000  846.000000
#
#             bmi  diabetespedigreefunction        age   outcome
# mean  31.992578                  0.471876  33.240885  0.348958
# std    7.884160                  0.331329  11.760232  0.476951
# min    0.000000                  0.078000  21.000000  0.000000
# 25%   27.300000                  0.243750  24.000000  0.000000
# 50%   32.000000                  0.372500  29.000000  0.000000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pregnancies               768 non-null    int64
#  1   glucose                   768 non-null    int64
#  2   bloodpressure             768 non-null    int64
#  3   skinthickness             768 non-null    int64
#  4   insulin                   768 non-null    int64
#  5   bmi                       768 non-null    float64
#  6   diabetespedigreefunction  768 non-null    float64
#  7   age                       768 non-null    int64
#  8   outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# # OUTLIERS CHECKING

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=df1.columns.values
ncol=30
nrows=34

# %%
collist
# Out:
# array(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness',
#        'insulin', 'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype=object)

# %% [markdown]
# # skewness

# %%
df1.skew()
# Out:
# pregnancies                 0.901674
# glucose                     0.173754
# bloodpressure              -1.843608
# skinthickness               0.109372
# insulin                     2.272251
# bmi                        -0.428982
# diabetespedigreefunction    1.919911
# age                         1.129597
# outcome                     0.635017
# dtype: float64

# %%
sns.distplot(df1["pregnancies"])
# Out:
# <AxesSubplot:xlabel='pregnancies', ylabel='Density'>

# %%
sns.distplot(df1["glucose"])
# Out:
# <AxesSubplot:xlabel='glucose', ylabel='Density'>

# %%
sns.distplot(df1["bloodpressure"])
# Out:
# <AxesSubplot:xlabel='bloodpressure', ylabel='Density'>

# %%
sns.distplot(df1["skinthickness"])
# Out:
# <AxesSubplot:xlabel='skinthickness', ylabel='Density'>

# %%
sns.distplot(df1["insulin"])
# Out:
# <AxesSubplot:xlabel='insulin', ylabel='Density'>

# %%
sns.distplot(df1["bmi"])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %%
sns.distplot(df1["age"])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(df1["diabetespedigreefunction"])
# Out:
# <AxesSubplot:xlabel='diabetespedigreefunction', ylabel='Density'>

# %%
sns.distplot(df1["outcome"])
# Out:
# <AxesSubplot:xlabel='outcome', ylabel='Density'>

# %% [markdown]
# # Data Cleaning

# %%
df1.corr()['outcome'].sort_values()
# Out:
# bloodpressure               0.065068
# skinthickness               0.074752
# insulin                     0.130548
# diabetespedigreefunction    0.173844
# pregnancies                 0.221898
# age                         0.238356
# bmi                         0.292695
# glucose                     0.466581
# outcome                     1.000000
# Name: outcome, dtype: float64

# %%
delete = pd.DataFrame([["0.065068","bloodpressure","No","Alot"],["0.074752","skinthickness","No","Alot"]],
                     columns=["corelation with target","column nmame","normalized","outlier"])
delete
# Out:
#   corelation with target   column nmame normalized outlier
# 0               0.065068  bloodpressure         No    Alot
# 1               0.074752  skinthickness         No    Alot

# %%
df=df1.drop(["bloodpressure","skinthickness"],axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [106], in <cell line: 1>()
# ----> 1 df=df1.drop(["bloodpressure","skinthickness"],axis=1)
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
# ...

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# IQR PROXIMITY RULE

# %%
df1
# Out:
#      pregnancies  glucose  insulin   bmi  diabetespedigreefunction  age  \
# 0              6      148        0  33.6                     0.627   50
# 1              1       85        0  26.6                     0.351   31
# 2              8      183        0  23.3                     0.672   32
# 3              1       89       94  28.1                     0.167   21
# 4              0      137      168  43.1                     2.288   33
# ..           ...      ...      ...   ...                       ...  ...
# 763           10      101      180  32.9                     0.171   63
# 764            2      122        0  36.8                     0.340   27
# 765            5      121      112  26.2                     0.245   30
# 766            1      126        0  30.1                     0.349   47
# 767            1       93        0  30.4                     0.315   23
#
#      outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
# ..       ...
# ...

# %%
from scipy.stats import zscore

# %%
np.abs(34)
# Out:
# 34

# %%
np.abs(zscore(df1))
# Out:
#      pregnancies   glucose   insulin       bmi  diabetespedigreefunction  \
# 0       0.639947  0.848324  0.692891  0.204013                  0.468492
# 1       0.844885  1.123396  0.692891  0.684422                  0.365061
# 2       1.233880  1.943724  0.692891  1.103255                  0.604397
# 3       0.844885  0.998208  0.123302  0.494043                  0.920763
# 4       1.141852  0.504055  0.765836  1.409746                  5.484909
# ..           ...       ...       ...       ...                       ...
# 763     1.827813  0.622642  0.870031  0.115169                  0.908682
# 764     0.547919  0.034598  0.692891  0.610154                  0.398282
# 765     0.342981  0.003301  0.279594  0.735190                  0.685193
# 766     0.844885  0.159787  0.692891  0.240205                  0.371101
# 767     0.844885  0.873019  0.692891  0.202129                  0.473785
#
#           age   outcome
# 0    1.425995  1.365896
# 1    0.190672  0.732120
# ...

# %%
import numpy as np
z=np.abs(zscore(df1))
z.shape
# Out:
# (768, 7)

# %%
type(z)
# Out:
# pandas.core.frame.DataFrame

# %%
np.where(z>3)
# Out:
# (array([  4,   8,   9,  13,  45,  49,  58,  60,  75,  81,  88, 111, 123,
#         145, 153, 159, 177, 182, 186, 220, 228, 228, 247, 286, 298, 330,
#         342, 349, 370, 370, 371, 371, 395, 409, 415, 426, 445, 445, 453,
#         455, 459, 486, 494, 502, 522, 584, 593, 621, 645, 655, 666, 673,
#         684, 684, 695, 706, 753], dtype=int64),
#  array([4, 2, 3, 2, 4, 3, 4, 3, 1, 3, 0, 2, 5, 3, 2, 0, 3, 1, 2, 2, 2, 4,
#         2, 2, 0, 4, 1, 1, 2, 4, 3, 4, 4, 2, 2, 3, 3, 4, 5, 0, 5, 2, 3, 1,
#         3, 2, 4, 4, 2, 2, 5, 3, 3, 5, 2, 3, 2], dtype=int64))

# %%
z.iloc[9]
# Out:
# pregnancies                 1.233880
# glucose                     0.128489
# insulin                     0.692891
# bmi                         4.060474
# diabetespedigreefunction    0.724455
# age                         1.766346
# outcome                     1.365896
# Name: 9, dtype: float64

# %%
len(np.where(z>3)[0])
# Out:
# 57

# %%
df1_new=df1[(z<3).all(axis=1)]

# %%
print("old DataFrame",df1.shape)
print("new DataFrame",df1_new.shape)
print("total Dropped rows",df1.shape[0]-df1_new.shape[0])
# Out:
# old DataFrame (768, 7)
# new DataFrame (716, 7)
# total Dropped rows 52

# %% [markdown]
# # Seprate the Data

# %%
x = df1_new.iloc[:,:-1]

# %%
y = df1_new.iloc[:,-1]

# %%
x

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 5      0
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: outcome, Length: 716, dtype: int64

# %% [markdown]
# # Transforming the data to remove skewness:

# %%
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method='yeo-johnson')

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x
# Out:
# array([[ 0.81766344,  0.95218058, -1.00223104,  0.28114356,  0.86495337,
#          1.39031405],
#        [-0.84957557, -1.28238174, -1.00223104, -0.83047682, -0.16002044,
#          0.12808007],
#        [ 1.20277392,  1.82893792, -1.00223104, -1.43279399,  0.98450779,
#          0.23328673],
#        ...,
#        [ 0.59040907,  0.13114807,  0.96157194, -0.9003888 , -0.75346236,
#          0.0156547 ],
#        [-0.84957557,  0.29534181, -1.00223104, -0.25021575, -0.1698999 ,
#          1.26101626],
#        [-0.84957557, -0.92550642, -1.00223104, -0.2028927 , -0.34504064,
#         -1.05311184]])

# %%
x.ndim
# Out:
# 2

# %%
x.mean()
# Out:
# 2.395972929679877e-15

# %%
round(-1.26 * 10**(-17),15)
# Out:
# -0.0

# %%
x.std()
# Out:
# 1.0

# %% [markdown]
# since the outcome has only two classes we will use classification model

# %%
df1.outcome.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df1.outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: outcome, dtype: int64

# %% [markdown]
# # Balance the data

# %%
# over sampling method
# undersampling
# random oversampling
# stacking

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %%
lr = LogisticRegression()
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print("At random state", i,"The model performs very well")
        print("At random state", i)
        print("The training accuracy score is:- ", round(accuracy_score(y_train,pred_train)*100,1))
        print("Testing accuracy score is:-", round(accuracy_score(y_test,pred_test)*100,1),'\n\n')
# Out:
# At random state 51 The model performs very well
# At random state 51
# The training accuracy score is:-  77.8
# Testing accuracy score is:- 77.8
#
#
# At random state 86 The model performs very well
# At random state 86
# The training accuracy score is:-  77.8
# Testing accuracy score is:- 77.8
#
#
# At random state 90 The model performs very well
# At random state 90
# The training accuracy score is:-  78.5
# Testing accuracy score is:- 78.5
#
#
# At random state 93 The model performs very well
# At random state 93
# The training accuracy score is:-  77.8
# Testing accuracy score is:- 77.8
#
#
# At random state 127 The model performs very well
# At random state 127
# The training accuracy score is:-  78.5
# Testing accuracy score is:- 78.5
#
#
# At random state 135 The model performs very well
# At random state 135
# The training accuracy score is:-  77.8
# Testing accuracy score is:- 77.8
#
#
# At random state 185 The model performs very well
# At random state 185
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=90)

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_train=lr.predict(x_train)

# %%
pred_test=lr.predict(x_test)

# %%
accuracy_score(y_train,pred_train)
# Out:
# 0.784965034965035

# %%
accuracy_score(y_test,pred_test)
# Out:
# 0.7847222222222222

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85       107
#            1       0.57      0.65      0.61        37
#
#     accuracy                           0.78       144
#    macro avg       0.72      0.74      0.73       144
# weighted avg       0.80      0.78      0.79       144

# %% [markdown]
# # cross validation of Loistic regression

# %%
pred_lr = lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss = accuracy_score(y_test,pred_lr)

# %%
************lss
# Out:
# 0.7847222222222222

# %%
for j in range(4,10):
    lsscore = cross_val_score(lr,x,y,cv=j)
    print(lsscore)
    lsc = lsscore.mean()
    print("At cv:-",j)
    print("cross validation score is :-",lsc*100)
    print("accuracy_score is:-", lss*100)
    print("\n")
# Out:
# [0.75977654 0.75418994 0.76536313 0.80446927]
# At cv:- 4
# cross validation score is :- 77.09497206703911
# accuracy_score is:- 78.47222222222221
#
#
# [0.75694444 0.75524476 0.75524476 0.81818182 0.76923077]
# At cv:- 5
# cross validation score is :- 77.09693084693085
# accuracy_score is:- 78.47222222222221
#
#
# [0.73333333 0.79166667 0.74789916 0.74789916 0.83193277 0.78991597]
# At cv:- 6
# cross validation score is :- 77.37745098039215
# accuracy_score is:- 78.47222222222221
#
#
# [0.72815534 0.78640777 0.73529412 0.7745098  0.73529412 0.85294118
#  0.78431373]
# At cv:- 7
# cross validation score is :- 77.09880068532267
# accuracy_score is:- 78.47222222222221
#
#
# [0.71111111 0.8        0.72222222 0.77777778 0.75280899 0.78651685
#  0.82022472 0.80898876]
# At cv:- 8
# cross validation score is :- 77.2456304619226
# accuracy_score is:- 78.47222222222221
#
#
# [0.725      0.8125     0.7625     0.725      0.775      0.72151899
#  0.86075949 0.78481013 0.81012658]
# At cv:- 9
# ...

# %%
lsscore_selected = cross_val_score(lr,x,y,cv=9).mean()
print("The cv scoe is :", lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv scoe is : 0.7752461322081574
# The accuracy score is:  0.7847222222222222

# %%
from sklearn.metrics import confusion_matrix

# %%
lr
# Out:
# LogisticRegression()

# %%
def model_selection(algorithm_instance,x_train,y_train,x_test,y_test):
    algorithm_instance.fit(x_train,y_train)
    model_1_pred_train = algorithm_instance.predict(x_train)
    model_1_pred_test = algorithm_instance.predict(x_test)
    print('accuracy of the training model:', accuracy_score(y_train,model_1_pred_train))
    print('accuracy of the test data:', accuracy_score(y_test,model_1_pred_test))
    print('classification report for test data \n', classification_report(y_test,model_1_pred_test))
    print('classification report for train data \n', classification_report(y_train,model_1_pred_train))
    print('confusion matrix: \n', confusion_matrix(y_test, model_1_pred_test))

# %%
model_selection(lr, x_train, y_train , x_test, y_test)
# Out:
# accuracy of the training model: 0.784965034965035
# accuracy of the test data: 0.7847222222222222
# classification report for test data
#                precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85       107
#            1       0.57      0.65      0.61        37
#
#     accuracy                           0.78       144
#    macro avg       0.72      0.74      0.73       144
# weighted avg       0.80      0.78      0.79       144
#
# classification report for train data
#                precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       366
#            1       0.74      0.62      0.67       206
#
#     accuracy                           0.78       572
#    macro avg       0.77      0.75      0.76       572
# weighted avg       0.78      0.78      0.78       572
#
# confusion matrix:
#  [[89 18]
#  [13 24]]

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()

# %%
model_selection(dt, x_train, y_train, x_test, y_test)
# Out:
# accuracy of the training model: 1.0
# accuracy of the test data: 0.7638888888888888
# classification report for test data
#                precision    recall  f1-score   support
#
#            0       0.86      0.81      0.84       107
#            1       0.53      0.62      0.57        37
#
#     accuracy                           0.76       144
#    macro avg       0.70      0.72      0.71       144
# weighted avg       0.78      0.76      0.77       144
#
# classification report for train data
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       366
#            1       1.00      1.00      1.00       206
#
#     accuracy                           1.00       572
#    macro avg       1.00      1.00      1.00       572
# weighted avg       1.00      1.00      1.00       572
#
# confusion matrix:
#  [[87 20]
#  [14 23]]

# %% [markdown]
# SVC
# KNearestClassifier
# RandomForestClassifier
# SGDCClassifier
# Adaboost
# Gradient Boosting
# XGBoost

# %% [markdown]
# # The Model with Outliers:

# %% [raw]
# from sklearn.metrics import roc_curve, auc
# fpr, tpr, thresholds = roc_curve(pred_test,y_test)
# roc_auc = auc(fpr,tpr)
#
# plt.figure()
# plt.plot(fpr, tpr, color = "red", lw=10, label = "ROC curve (area = %0.1f)" % roc_auc)
# plt.plot([0, 1], [0, 1], color= "blue", lw=10, linestyle="--" )
# plt.xlim([0.0,1.0])
# plt.ylim([0.0,1.0])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('receiver operating characeristic')
# plt.legend(loc="lower right")
# plt.show()

# %% [markdown]
# # Model Saving

# %%
import pickle
filename = "inhouse_diabetes.pkl"
pickle.dump(lr, open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
a = np.array(y_test)
predicted=np.array(lr.predict(x_test))

# %%
df1_com=pd.DataFrame({"original":a,"predicted":predicted}, index= range(len(a)))

# %%
df1_com
# Out:
#      original  predicted
# 0           0          0
# 1           0          0
# 2           1          0
# 3           0          0
# 4           0          1
# ..        ...        ...
# 139         1          1
# 140         0          1
# 141         0          0
# 142         0          0
# 143         1          1
#
# [144 rows x 2 columns]
