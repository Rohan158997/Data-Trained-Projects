# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("salaries.csv")

# %%
data
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
data.sample(5)
# Out:
#      rank discipline  yrs.since.phd  yrs.service     sex  salary
# 62   Prof          B             33           31    Male  109785
# 236  Prof          A             25           25    Male  114000
# 361  Prof          A             23           15  Female  109646
# 150  Prof          B             14           12    Male  128148
# 189  Prof          B             25           19    Male  153750

# %%
data.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %%
data.tail()
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035

# %%
data.dtypes
# Out:
# rank             object
# discipline       object
# yrs.since.phd     int64
# yrs.service       int64
# sex              object
# salary            int64
# dtype: object

# %%
data.drop(["sex","rank","discipline"], axis=1, inplace=True)

# %%
data
# Out:
#      yrs.since.phd  yrs.service  salary
# 0               19           18  139750
# 1               20           16  173200
# 2                4            3   79750
# 3               45           39  115000
# 4               40           41  141500
# ..             ...          ...     ...
# 392             33           30  103106
# 393             31           19  150564
# 394             42           25  101738
# 395             25           15   95329
# 396              8            4   81035
#
# [397 rows x 3 columns]

# %%
plt.scatter(data["yrs.since.phd"],data["salary"])
plt.xlabel("years since phd")
plt.ylabel("salary")
plt.show()

# %%
plt.scatter(data["yrs.service"],data["salary"])

# %% [markdown]
# from above plots we can say salary is more dependent on years since phd than years of experience

# %%
plt.figure(figsize=(8,10))
sns.heatmap(data.corr(), annot=True,  vmin=-1.0, vmax=1.0)
plt.show()

# %%
data.isnull().sum()
# Out:
# yrs.since.phd    0
# yrs.service      0
# salary           0
# dtype: int64

# %%
y = data["salary"].values
x=data.drop("salary", axis=1).values

# %%
y
# Out:
# array([139750, 173200,  79750, 115000, 141500,  97000, 175000, 147765,
#        119250, 129000, 119800,  79800,  77700,  78000, 104800, 117150,
#        101000, 103450, 124750, 137000,  89565, 102580,  93904, 113068,
#         74830, 106294, 134885,  82379,  77000, 118223, 132261,  79916,
#        117256,  80225,  80225,  77000, 155750,  86373, 125196, 100938,
#        146500,  93418, 101299, 231545,  94384, 114778,  98193, 151768,
#        140096,  70768, 126621, 108875,  74692, 106639, 103760,  83900,
#        117704,  90215, 100135,  75044,  90304,  75243, 109785, 103613,
#         68404, 100522, 101000,  99418, 111512,  91412, 126320, 146856,
#        100131,  92391, 113398,  73266, 150480, 193000,  86100,  84240,
#        150743, 135585, 144640,  88825, 122960, 132825, 152708,  88400,
#        172272, 107008,  97032, 105128, 105631, 166024, 123683,  84000,
#         95611, 129676, 102235, 106689, 133217, 126933, 153303, 127512,
# ...

# %%
x
# Out:
# array([[19, 18],
#        [20, 16],
#        [ 4,  3],
#        [45, 39],
#        [40, 41],
#        [ 6,  6],
#        [30, 23],
#        [45, 45],
#        [21, 20],
#        [18, 18],
#        [12,  8],
#        [ 7,  2],
#        [ 1,  1],
#        [ 2,  0],
#        [20, 18],
#        [12,  3],
#        [19, 20],
#        [38, 34],
#        [37, 23],
#        [39, 36],
#        [31, 26],
#        [36, 31],
#        [34, 30],
#        [24, 19],
#        [13,  8],
#        [21,  8],
#        [35, 23],
#        [ 5,  3],
#        [11,  0],
#        [12,  8],
#        [20,  4],
#        [ 7,  2],
#        [13,  9],
#        [ 4,  2],
#        [ 4,  2],
#        [ 5,  0],
#        [22, 21],
#        [ 7,  4],
#        [41, 31],
#        [ 9,  9],
#        [23,  2],
#        [23, 23],
#        [40, 27],
#        [38, 38],
#        [19, 19],
#        [25, 15],
#        [40, 28],
#        [23, 19],
#        [25, 25],
#        [ 1,  1],
#        [28, 28],
#        [12, 11],
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/4,random_state=101)

# %%
x_train.size
# Out:
# 594

# %%
x_train
# Out:
# array([[20, 20],
#        [40, 40],
#        [12,  0],
#        [19, 20],
#        [ 4,  1],
#        [22, 21],
#        [39, 36],
#        [13,  8],
#        [27, 21],
#        [28, 27],
#        [33, 19],
#        [15, 10],
#        [13,  6],
#        [14,  9],
#        [36, 30],
#        [37, 27],
#        [11,  8],
#        [23, 23],
#        [ 7,  2],
#        [13,  9],
#        [ 9,  3],
#        [39, 39],
#        [28, 13],
#        [17,  2],
#        [ 5,  3],
#        [27, 27],
#        [ 9,  7],
#        [16, 16],
#        [10,  5],
#        [ 4,  3],
#        [35, 30],
#        [ 3,  1],
#        [24, 22],
#        [15, 10],
#        [ 9,  8],
#        [ 4,  1],
#        [35, 35],
#        [22, 15],
#        [35, 25],
#        [25, 18],
#        [48, 53],
#        [ 2,  2],
#        [17, 17],
#        [11,  1],
#        [49, 60],
#        [12,  8],
#        [27, 14],
#        [ 6,  6],
#        [32, 25],
#        [ 4,  2],
#        [21,  2],
#        [28, 23],
# ...

# %%
y_train
# Out:
# array([122400, 119700, 105000, 101000,  72500, 155750, 117515,  74830,
#        125192, 115800, 145098,  81500, 107150, 108100, 134800, 103600,
#         82099,  93418,  79916, 117256,  73800, 111350, 170500, 126320,
#         69200, 156938,  70000, 134550,  97032,  80139, 131950,  86100,
#         96614, 115435,  90304,  74856, 100351, 166800, 168635, 181257,
#         90000,  89516, 124312, 104800, 192253, 118223, 147349,  95408,
#        128464,  80225,  96545, 113398, 162200, 146800, 165000, 174500,
#         89650,  95436,  89565,  73500, 150564,  87800, 160400,  98510,
#         73000, 136000,  74000,  88825, 143940, 151575, 103700, 108200,
#        163200, 126300, 100600, 109954,  92391,  83900, 104428, 132825,
#         69700, 137167, 100944, 146000,  93164,  84716, 120806,  91000,
#         77000, 122875,  86373,  80225, 173200,  74000, 153303, 114000,
#        136660, 126933, 128148, 105450,  62884, 126431, 101100,  95329,
# ...

# %%
x_test.size
# Out:
# 200

# %%
y_test.size
# Out:
# 100

# %% [markdown]
# Linear Regression

# %%
LR=LinearRegression()

# %%
LR
# Out:
# LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_LR=LR.predict(x_test)

# %%
x_test
# Out:
# array([[41, 31],
#        [18, 10],
#        [23, 10],
#        [40, 31],
#        [10,  7],
#        [17, 16],
#        [ 7,  4],
#        [29, 19],
#        [ 9,  7],
#        [ 3,  3],
#        [40, 36],
#        [25, 19],
#        [42, 25],
#        [13, 10],
#        [14, 10],
#        [38, 36],
#        [18, 10],
#        [16, 11],
#        [13,  8],
#        [36, 19],
#        [23, 21],
#        [42, 18],
#        [30, 14],
#        [16,  9],
#        [38, 38],
#        [ 9,  9],
#        [43, 40],
#        [21, 20],
#        [34, 33],
#        [16, 11],
#        [29, 27],
#        [37, 37],
#        [28, 25],
#        [30, 31],
#        [20, 17],
#        [27, 16],
#        [17, 11],
#        [ 6,  3],
#        [38, 38],
#        [45, 45],
#        [29, 27],
#        [ 3,  1],
#        [28, 28],
#        [15,  7],
#        [13, 11],
#        [42, 25],
#        [21, 18],
#        [32, 30],
#        [ 4,  0],
#        [41, 33],
#        [26, 27],
#        [ 2,  0],
# ...

# %%
y_test
# Out:
# array([125196, 107500, 145200, 131205, 105128, 135585,  74500, 100131,
#        113600,  92000,  97150, 153750, 101738, 103750, 104350, 119450,
#         83850, 145350,  78182, 117555, 117704, 194800, 102235, 106639,
#        114596,  95642, 101036, 119250, 189409,  88175, 139219, 152708,
#        111751, 162221,  81285, 127100, 148800,  77081, 231545, 107550,
#        150500,  72500, 106300, 128400, 106231, 133217, 152664,  92550,
#         84000,  88600, 142500,  85000, 141500, 109707, 128250, 113278,
#         73877,  84500, 108875,  70700,  78500, 205500, 102000, 137000,
#         83001, 183800, 118971, 100522, 140096, 124750, 117150,  92000,
#         78000, 105890,  89942, 141136, 103450, 107008,  90215,  83000,
#        107309, 176500,  88000, 116518, 145028, 126000, 113341,  91412,
#         91227, 130664, 122500, 140300, 121946,  68404, 100938, 107986,
#        129000, 150000,  77700, 101210], dtype=int64)

# %%
y_pred_LR
# Out:
# array([132921.83112397, 111635.34808672, 119714.98684725, 131305.90337186,
#        100976.47682147, 105482.31883141,  98397.24431675, 122604.90110509,
#         99360.54906936,  92689.71689219, 127524.98545253, 116141.19009666,
#        139074.86037927, 103555.70932619, 105171.63707829, 124293.12994832,
#        111635.34808672, 107647.30899864, 105068.07649392, 133916.39536983,
#        111396.96742472, 144368.14546633, 128001.74677653, 109159.67616637,
#        122780.76278059,  97848.18190163, 129348.03437339, 108921.29550437,
#        120097.96969149, 107647.30899864, 116555.43243416, 121921.01861235,
#        116451.87184979, 115146.6258508 , 109573.91850387, 121641.59635247,
#        109263.23675074,  97537.50014851, 122780.76278059, 128798.97195827,
#        116555.43243416,  94202.08405992, 114183.32109819, 109056.115582  ,
#        102799.52574232, 139074.86037927, 110433.66267211, 119134.66493888,
# ...

# %%
diff_LR=y_pred_LR-y_test

# %%
rep_df = pd.concat([pd.Series(y_pred_LR),pd.Series(y_test),pd.Series(diff_LR)],axis=1)

# %%
rep_df.sample()
# Out:
#                 0      1             2
# 16  111635.348087  83850  27785.348087
